# %%
#Loading the required libraries
import pandas as pd 
from matplotlib import pyplot as plt  
import seaborn as sns

# %%
fifa = pd.read_csv('players_20.csv', encoding="latin1")

# %%
fifa.head()
# Out:
#    sofifa id                                         player url  \
# 0   15610750  https://sofifa.com/player/15610750/lionel-mess...
# 1      20801  https://sofifa.com/player/20902/c-ronaldo-dos-...
# 2     183898    https://sofifa.com/player/183898/angel-di-maria
# 3   14513950  https://sofifa.com/player/14513950/diego-maradona
# 4   13361774  https://sofifa.com/player/13361774/edson-arant...
#
#        short name                            long name  age         dob  \
# 0         L Messi                         Lionel Messi   38   24/6/1987
# 1       C Ronaldo  Cristiano Ronaldo dos Santos Aveiro   40    5/2/1985
# 2  Angel Di Maria      Angel Fabian Di Maria Hernandez   36   14/2/1988
# 3  Diego Maradona               Diego Armando Maradona   65  10/30/1960
# 4            Pele          Edson Arantes do Nascimento   82  10/23/1940
#
#    height cm  weight kg nationality                   club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa id
# player url
# short name
# long name
# age
# dob
# height cm
# weight kg
# nationality
# club
# overall
# potential
# value eur
# wage eur
# player position
# preferred foot
# international reputation
# weak foot
# skill moves
# works rate
# body type
# real face
# release clause eur
# player tags
# team position
# team jersey name
# loaned frm
# joined
# contract valid until
# nation position
# nation jersey number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk driving
# gk handling
# gk kicking
# gk reflexes
# gk speed
# gk possitioning
# player traits
# attacking crossing
# attacking finishing
# attacking heading accuracy
# attacking short passing
# attacking volleys
# skill dribblings
# skill curve
# skill fk accuracy
# skill long passing
# skill ball control
# movement acceleration
# movement sprit speed
# movement agility
# movement reactions
# movement balance
# power shot power
# power jumping
# power stamina
# power strength
# power long shots
# ...

# %%
fifa.shape
# Out:
# (10, 104)

# %%
6*104
# Out:
# 624

# %%
72/6
# Out:
# 12.0

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# Argentina    5
# Brazil       4
# Portugal     1
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# Argentina    5
# Brazil       4
# Portugal     1
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['Argentina', 'Brazil', 'Portugal'], dtype='object', name='nationality')

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# nationality
# Argentina    5
# Brazil       4
# Portugal     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(list(fifa['nationality'].value_counts()[0:5])))
plt.show()

# %%
players_salary=fifa[['short name','wage eur']]

# %%
players_salary.head()
# Out:
#        short name wage eur
# 0         L Messi       65
# 1       C Ronaldo     4500
# 2  Angel Di Maria   18,500
# 3  Diego Maradona     7800
# 4            Pele     4500

# %%
player_salary= players_salary.sort_values(by=['wage eur'],ascending=False)

# %%
player_salary.head()
# Out:
#             short name wage eur
# 7    Emiliano Martínez     8790
# 8  Ronaldo Nazario(R9)     7820
# 3       Diego Maradona     7800
# 5           Neymar Jr.      650
# 0              L Messi       65

# %%
plt.figure(figsize=(8,6))
plt.bar(list(player_salary['short name'])[0:5], list(player_salary['wage eur'])[0:5],color=['red','blue','yellow','green','brown'])
plt.show()

# %%
fifa['nationality']=='Argentina'
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9    False
# Name: nationality, dtype: bool

# %%
#Argentina
Argentina=fifa[fifa['nationality']=='Argentina']
Argentina.head(10)
# Out:
#    sofifa id                                         player url  \
# 0   15610750  https://sofifa.com/player/15610750/lionel-mess...
# 2     183898    https://sofifa.com/player/183898/angel-di-maria
# 3   14513950  https://sofifa.com/player/14513950/diego-maradona
# 6     246191    https://spfifa.com/player/246191/julian-alvarez
# 7     202811  https://sofifa.com/player/202811/emiliano-mart...
#
#           short name                        long name  age         dob  \
# 0            L Messi                     Lionel Messi   38   24/6/1987
# 2     Angel Di Maria  Angel Fabian Di Maria Hernandez   36   14/2/1988
# 3     Diego Maradona           Diego Armando Maradona   65  10/30/1960
# 6     Julian Alvarez                   Julian Alvarez   25   1/31/2000
# 7  Emiliano Martínez  Damián Emiliano Martínez Romero   33    9/2/1992
#
#    height cm  weight kg nationality                   club  ...   lwb   ldm  \
# ...

# %%
Argentina.sort_values(by=['height cm'],ascending=False).head()
# Out:
#    sofifa id                                         player url  \
# 7     202811  https://sofifa.com/player/202811/emiliano-mart...
# 2     183898    https://sofifa.com/player/183898/angel-di-maria
# 6     246191    https://spfifa.com/player/246191/julian-alvarez
# 0   15610750  https://sofifa.com/player/15610750/lionel-mess...
# 3   14513950  https://sofifa.com/player/14513950/diego-maradona
#
#           short name                        long name  age         dob  \
# 7  Emiliano Martínez  Damián Emiliano Martínez Romero   33    9/2/1992
# 2     Angel Di Maria  Angel Fabian Di Maria Hernandez   36   14/2/1988
# 6     Julian Alvarez                   Julian Alvarez   25   1/31/2000
# 0            L Messi                     Lionel Messi   38   24/6/1987
# 3     Diego Maradona           Diego Armando Maradona   65  10/30/1960
#
#    height cm  weight kg nationality                   club  ...   lwb   ldm  \
# ...

# %%
Argentina.sort_values(by=['weight kg'],ascending=False).head()
# Out:
#    sofifa id                                         player url  \
# 7     202811  https://sofifa.com/player/202811/emiliano-mart...
# 3   14513950  https://sofifa.com/player/14513950/diego-maradona
# 2     183898    https://sofifa.com/player/183898/angel-di-maria
# 0   15610750  https://sofifa.com/player/15610750/lionel-mess...
# 6     246191    https://spfifa.com/player/246191/julian-alvarez
#
#           short name                        long name  age         dob  \
# 7  Emiliano Martínez  Damián Emiliano Martínez Romero   33    9/2/1992
# 3     Diego Maradona           Diego Armando Maradona   65  10/30/1960
# 2     Angel Di Maria  Angel Fabian Di Maria Hernandez   36   14/2/1988
# 0            L Messi                     Lionel Messi   38   24/6/1987
# 6     Julian Alvarez                   Julian Alvarez   25   1/31/2000
#
#    height cm  weight kg nationality                   club  ...   lwb   ldm  \
# ...

# %%
Argentina.sort_values(by=['wage eur'],ascending=False).head()
# Out:
#    sofifa id                                         player url  \
# 7     202811  https://sofifa.com/player/202811/emiliano-mart...
# 3   14513950  https://sofifa.com/player/14513950/diego-maradona
# 0   15610750  https://sofifa.com/player/15610750/lionel-mess...
# 6     246191    https://spfifa.com/player/246191/julian-alvarez
# 2     183898    https://sofifa.com/player/183898/angel-di-maria
#
#           short name                        long name  age         dob  \
# 7  Emiliano Martínez  Damián Emiliano Martínez Romero   33    9/2/1992
# 3     Diego Maradona           Diego Armando Maradona   65  10/30/1960
# 0            L Messi                     Lionel Messi   38   24/6/1987
# 6     Julian Alvarez                   Julian Alvarez   25   1/31/2000
# 2     Angel Di Maria  Angel Fabian Di Maria Hernandez   36   14/2/1988
#
#    height cm  weight kg nationality                   club  ...   lwb   ldm  \
# ...

# %%
Argentina[['short name','wage eur']].sort_values(by=['wage eur'],ascending=False).head()
# Out:
#           short name wage eur
# 7  Emiliano Martínez     8790
# 3     Diego Maradona     7800
# 0            L Messi       65
# 6     Julian Alvarez    47500
# 2     Angel Di Maria   18,500

# %%
#Shorting

# %%
player_shorting = fifa[['short name','shooting']]

# %%
player_shorting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#        short name  shooting
# 0         L Messi      97.0
# 2  Angel Di Maria      83.0
# 1       C Ronaldo       NaN
# 3  Diego Maradona       NaN
# 4            Pele       NaN

# %%
#defending

# %%
player_defending=fifa[['short name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#        short name  defending nationality                   club
# 0         L Messi       48.0   Argentina           Inter Miami
# 1       C Ronaldo        NaN    Portugal               AI-Nassr
# 2  Angel Di Maria        NaN   Argentina  SL Benfica (Portugal)
# 3  Diego Maradona        NaN   Argentina                  Icons
# 4            Pele        NaN      Brazil                  Icons

# %%
real_madrid=fifa[fifa['club']=='real_mardeid']

# %%
real_madrid.sort_values(by=['wage eur'],ascending=False).head()
# Out:
# Empty DataFrame
# ...

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
# Empty DataFrame
# ...

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
# Empty DataFrame
# ...

# %%
real_madrid['nationality'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
