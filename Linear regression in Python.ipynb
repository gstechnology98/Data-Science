# %%
import pandas as pd

# %%
iris = pd.read_csv('iris_sample.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris[iris['sepal_width']>4]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 39           5.7          4.4           1.5          0.4  Iris-setosa

# %%
iris[iris['sepal_width']>2]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2           setosa
# 1            4.9          3.0           1.4          0.2           setosa
# 2            4.7          3.2           1.3          0.2           setosa
# 3            4.6          3.1           1.5          0.2           setosa
# 4            5.0          3.6           1.4          0.2           setosa
# ..           ...          ...           ...          ...              ...
# 73           5.7          2.6           3.5          1.0  Iris-versicolor
# 74           5.5          2.4           3.8          1.1  Iris-versicolor
# 75           5.5          2.4           3.7          1.0  Iris-versicolor
# 76           5.8          2.7           3.9          1.2  Iris-versicolor
# 77           6.0          2.7           5.1          1.6  Iris-versicolor
#
# [77 rows x 5 columns]

# %%
iris[iris['sepal_width']>1]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2           setosa
# 1            4.9          3.0           1.4          0.2           setosa
# 2            4.7          3.2           1.3          0.2           setosa
# 3            4.6          3.1           1.5          0.2           setosa
# 4            5.0          3.6           1.4          0.2           setosa
# ..           ...          ...           ...          ...              ...
# 73           5.7          2.6           3.5          1.0  Iris-versicolor
# 74           5.5          2.4           3.8          1.1  Iris-versicolor
# 75           5.5          2.4           3.7          1.0  Iris-versicolor
# 76           5.8          2.7           3.9          1.2  Iris-versicolor
# 77           6.0          2.7           5.1          1.6  Iris-versicolor
#
# [78 rows x 5 columns]

# %%
iris[iris['sepal_width']>2]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2           setosa
# 1            4.9          3.0           1.4          0.2           setosa
# 2            4.7          3.2           1.3          0.2           setosa
# 3            4.6          3.1           1.5          0.2           setosa
# 4            5.0          3.6           1.4          0.2           setosa
# ..           ...          ...           ...          ...              ...
# 73           5.7          2.6           3.5          1.0  Iris-versicolor
# 74           5.5          2.4           3.8          1.1  Iris-versicolor
# 75           5.5          2.4           3.7          1.0  Iris-versicolor
# 76           5.8          2.7           3.9          1.2  Iris-versicolor
# 77           6.0          2.7           5.1          1.6  Iris-versicolor
#
# [77 rows x 5 columns]

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
plt.show()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris, hue="species")
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y=iris[['sepal_length']]

# %%
x=iris[['sepal_width']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#     sepal_width
# 0           3.5
# 23          2.9
# 17          3.1
# 21          3.3
# 73          2.6

# %%
x_test.head()
# Out:
#     sepal_width
# 24          3.5
# 46          3.1
# 60          3.0
# 36          3.0
# 31          3.4

# %%
y_train.head()
# Out:
#     sepal_length
# 0            5.1
# 23           6.6
# 17           6.9
# 21           6.3
# 73           5.7

# %%
y_test.head()
# Out:
#     sepal_length
# 24           5.1
# 46           6.9
# 60           5.6
# 36           4.8
# 31           5.0

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#     sepal_length
# 24           5.1
# 46           6.9
# 60           5.6
# 36           4.8
# 31           5.0

# %%
y_pred[0:5]
# Out:
# array([[5.51645166],
#        [5.59019281],
#        [5.6086281 ],
#        [5.6086281 ],
#        [5.53488695]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.5180463425636571

# %%
 #model-2

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y=iris[['sepal_length']]

# %%
x=iris[['sepal_width','petal_length','petal_width']]

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.10745960881227527

# %%
.
